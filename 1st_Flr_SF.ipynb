# %% [markdown]
# # 1. Set up

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
color = sns.color_palette()
sns.set_style('darkgrid')

# %%
import pandas as pd
X_train = pd.read_csv("data/X_train.csv")
y_train = pd.read_csv("data/y_train.csv")

train = pd.concat((X_train,y_train),axis=1)

# %% [markdown]
# # Analyse

# %%
sns.boxplot(x=train['1st Flr SF'])
# Out:
# <AxesSubplot: xlabel='1st Flr SF'>

# %%
train.loc[train['1st Flr SF']>2500,'1st Flr SF'] = 2500

# %%
sns.boxplot(x=train['Gr Liv Area'])
# Out:
# <AxesSubplot: xlabel='Gr Liv Area'>

# %%
train.loc[train['Gr Liv Area']>3000,'Gr Liv Area'] = 3000

# %% [markdown]
# # 3. Test de l'hypothèse

# %%
X_train = pd.read_csv("data/X_train.csv")
X_test = pd.read_csv("data/X_test.csv")

# %%
import utils

utils.regression()
# Out:
# MAE on train data:  20289.235596149567
# MAE on test data:  21324.929684826453
# (20289.235596149567, 21324.929684826453)

# %%
X_train.loc[X_train['1st Flr SF']>3000,'1st Flr SF'] = 3000 
X_test.loc[X_test['1st Flr SF']>3000,'1st Flr SF'] = 3000

# %%
import utils

utils.regression(X_train=X_train, X_test=X_test)
# Out:
# MAE on train data:  20448.348823527198
# MAE on test data:  21324.2016949027
# (20448.348823527198, 21324.2016949027)

# %% [markdown]
# Conlusion: on ne voit pas d'amélioration
